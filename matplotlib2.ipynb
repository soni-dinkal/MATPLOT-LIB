# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\DINKAL\\Desktop\\BIA\\drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
counts  = [400, 340, 200]
plt.pie(counts, labels = ["SG", "CG", "MN"], 
                colors = ["gold", "yellowgreen", "lightcoral"], 
                explode = (0.5, 0.1, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e5c0820a60>,
# ...
#  [Text(0.37091219702149736, 1.556413872368364, 'SG'),
#   Text(-0.9417592519639368, -0.7436998798845716, 'CG'),
#   Text(0.8632793143002754, -0.6817248898941907, 'MN')])

# %%
counts  = [400, 340, 200]
plt.pie(counts, labels = ["SG", "CG", "MN"], 
                colors = ["gold", "yellowgreen", "lightcoral"], 
                explode = (1, 1, 1))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e5c1dd8910>,
# ...
#  [Text(0.48682225859071526, 2.0427932074834776, 'SG'),
#   Text(-1.6480786909368894, -1.3014747897980004, 'CG'),
#   Text(1.6480786909368894, -1.3014747897980004, 'MN')])

# %%
counts  = [400, 340, 200]
plt.pie(counts, labels = ["SG", "CG", "MN"], 
                colors = ["gold", "yellowgreen", "lightcoral"], 
                explode = (0, 0, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1e5c1e03670>,
# ...
#  [Text(0.25500213545227945, 1.0700345372532503, 'SG'),
#   Text(-0.8632793143002754, -0.6817248898941907, 'CG'),
#   Text(0.8632793143002754, -0.6817248898941907, 'MN')])

# %%
import numpy as np
a = np.array([1, 2, 3, 12, 15, 22, 25, 26, 29, 32, 43, 54, 55, 59])
plt.hist(a, bins =8) # bins => how many portions on the x axis
plt.ylabel("Counts")
plt.xlabel("Something")
# Out:
# Text(0.5, 0, 'Something')

# %%
df.drop(["country", "continent"], axis = 1, inplace = True)
df
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
plt.figure(figsize=(5, 5))  
plt.pie(df["beer_servings"], labels=df["spirit_servings"], autopct='%1.1f%%', startangle=140) 
plt.title("Beer Servings & Spirit servings")
plt.axis('equal') 
plt.show()
